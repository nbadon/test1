# %% [markdown]
# # Data Analysis Project

# %% [markdown]
# ### Environment Setup

# %%
# %pip install numpy
# %pip install pandas
# %pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth',3000)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Data Import

# %%
df = pd.read_csv('Test 1_ Remitano survey 4_2020 - Test 1_ Remitano survey 4_2020.csv')

# %%
df.head()
# Out:
#                                   # What age range do you have?  \
# 0  6w46ukq2s3q0hg17q06w46ukqyj8cz6a                        > 40
# 1  aon05iax15oiaocz08iyq9m6nw0bx0cz                        > 40
# 2  rd4384zwi4f8qdc8zpkgrd4384zwsiqw                     31 - 40
# 3  5v23ormjjk7517pdic95v23r0v2l61l2                        < 18
# 4  1i9bju4z8s2gxicftve1i9bcwwsjzd6r                     18 - 25
#
#   What is your gender? Other Where are you from? Other.1  \
# 0                 Male   NaN            Malaysia     NaN
# 1                 Male   NaN            Malaysia     NaN
# 2                 Male   NaN            Malaysia     NaN
# 3                 Male   NaN               India     NaN
# 4                 Male   NaN               India     NaN
#
#    When did you join Remitano?  Buy Coins  Sell Coins  Withdraw coins  \
# 0                         2019  Buy Coins         NaN             NaN
# 1                         2017  Buy Coins  Sell Coins  Withdraw coins
# ...

# %% [markdown]
# ### Checking Number of Survey Respondents

# %%
df[["#"]].nunique()
# Out:
# #    910
# dtype: int64

# %% [markdown]
# ### Analysing Survey Data

# %%
df[["What age range do you have?"]].value_counts()
# Out:
# What age range do you have?
# 18 - 25                        277
# 31 - 40                        246
# 26 - 30                        207
# > 40                           159
# < 18                            21
# dtype: int64

# %%
df[["What is your gender?"]].value_counts()
# Out:
# What is your gender?
# Male                    793
# Female                  115
# dtype: int64

# %%
df[["Other"]].value_counts()
# Out:
# Other
# Lesbian    1
# No         1
# dtype: int64

# %%
df[["Where are you from?"]].value_counts()
# Out:
# Where are you from?
# Nigeria                279
# Malaysia               241
# Vietnam                123
# India                   69
# dtype: int64

# %%
df[["Other.1"]].value_counts()
# Out:
# Other.1
# Pakistan             35
# Tanzania             23
# Kenya                20
# Ghana                11
# pakistan             10
# South Africa          8
# Bangladesh            6
# Mongolia              4
# Philippines           4
# Nigeria               4
# USA                   4
# Uganda                4
# Zambia                4
# Thailand              3
# Singapore             3
# TANZANIA              2
# United states         2
# SINGAPORE             2
# Venezuela             2
# egypt                 2
# indonesia             2
# Nepal                 2
# Myanmar               2
# Australia             2
# ไทย                   2
# Indonesia             2
# Canada                2
# United state          1
# Cameroun              1
# Cameroonian           1
# Cameroon              1
# brunei                1
# canada                1
# Tunisia               1
# Cambodia              1
# Brunei Darussalam     1
# iran                  1
# kenya                 1
# ...

# %%
df[["When did you join Remitano?"]].value_counts()
# Out:
# When did you join Remitano?
# 2020                           485
# 2019                           182
# 2018                           110
# 2017                            98
# 2016                            35
# dtype: int64

# %% [markdown]
# ### Analysing: Which Features on Remitano did you use?

# %%
### Features Rank by Total Vote Count

df[["Buy Coins","Sell Coins", "Withdraw coins","Deposit Coins","Swap","Invest","Read articles on Forum","Participate in minigame on Forum"
    ,"Not using any of the above features","Used all"]].count()
# Out:
# Buy Coins                              434
# Sell Coins                             441
# Withdraw coins                         334
# Deposit Coins                          288
# Swap                                   139
# Invest                                 186
# Read articles on Forum                 123
# Participate in minigame on Forum        54
# Not using any of the above features     80
# Used all                               178
# dtype: int64

# %% [markdown]
# #### Number of Features Used per Respondent

# %%
df_feature_usage = df[["#","Buy Coins","Sell Coins", "Withdraw coins","Deposit Coins","Swap","Invest",
                       "Read articles on Forum","Participate in minigame on Forum"
                       ,"Not using any of the above features","Used all"]]

# %%
df_feature_usage["Feature Used"] = df_feature_usage[["Buy Coins","Sell Coins", "Withdraw coins","Deposit Coins","Swap","Invest",
                       "Read articles on Forum","Participate in minigame on Forum"]].count(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\3265640473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feature_usage["Feature Used"] = df_feature_usage[["Buy Coins","Sell Coins", "Withdraw coins","Deposit Coins","Swap","Invest",

# %%
df_feature_usage[["Feature Used"]].value_counts()
# Out:
# Feature Used
# 1               277
# 0               209
# 3               108
# 2                81
# 4                80
# 5                77
# 6                37
# 8                22
# 7                19
# dtype: int64

# %% [markdown]
# #### Analysing Respondents who only used 1 Feature

# %%
df_feature_usage_1 = df_feature_usage[df_feature_usage["Feature Used"]==1]

# %%
df_feature_usage_1['Feature'] = df_feature_usage_1[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',
                                                    'Swap', 'Invest', 'Read articles on Forum',
                                                    'Participate in minigame on Forum',]].fillna(method='bfill', axis=1).iloc[:, 0]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\561524004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feature_usage_1['Feature'] = df_feature_usage_1[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',

# %%
df_feature_usage_1[["Feature"]].value_counts()
# Out:
# Feature
# Buy Coins                           84
# Sell Coins                          70
# Invest                              43
# Withdraw coins                      26
# Read articles on Forum              22
# Swap                                12
# Deposit Coins                       10
# Participate in minigame on Forum    10
# dtype: int64

# %% [markdown]
# #### Analysing Respondents who used 2 Features

# %%
df_feature_usage_2 = df_feature_usage[df_feature_usage["Feature Used"]==2]

# %%
df_feature_usage_2['Feature Combined'] = df_feature_usage_2[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',
                                                             'Swap', 'Invest', 'Read articles on Forum',
                                                             'Participate in minigame on Forum']].fillna('').sum(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\3781310735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feature_usage_2['Feature Combined'] = df_feature_usage_2[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',

# %%
df_feature_usage_2[['Feature Combined']].value_counts()
# Out:
# Feature Combined
# Buy CoinsSell Coins                                       28
# Sell CoinsDeposit Coins                                   13
# Sell CoinsWithdraw coins                                  11
# Buy CoinsWithdraw coins                                    7
# Buy CoinsInvest                                            5
# Withdraw coinsDeposit Coins                                5
# Buy CoinsRead articles on Forum                            2
# Read articles on ForumParticipate in minigame on Forum     2
# Withdraw coinsParticipate in minigame on Forum             2
# Buy CoinsDeposit Coins                                     1
# Deposit CoinsSwap                                          1
# Sell CoinsInvest                                           1
# Sell CoinsSwap                                             1
# SwapParticipate in minigame on Forum                       1
# Withdraw coinsInvest                                       1
# dtype: int64

# %% [markdown]
# #### Analysing Respondents who used 3 Features

# %%
df_feature_usage_3 = df_feature_usage[df_feature_usage["Feature Used"]==3]

# %%
df_feature_usage_3['Feature Combined'] = df_feature_usage_3[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',
                                                             'Swap', 'Invest', 'Read articles on Forum',
                                                             'Participate in minigame on Forum']].fillna('').sum(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\3701716641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feature_usage_3['Feature Combined'] = df_feature_usage_3[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',

# %%
df_feature_usage_3[['Feature Combined']].value_counts()
# Out:
# Feature Combined
# Buy CoinsSell CoinsWithdraw coins                                   22
# Sell CoinsWithdraw coinsDeposit Coins                               19
# Buy CoinsSell CoinsInvest                                           12
# Buy CoinsSell CoinsRead articles on Forum                           10
# Buy CoinsSell CoinsSwap                                             10
# Buy CoinsSell CoinsDeposit Coins                                     8
# Buy CoinsWithdraw coinsDeposit Coins                                 7
# Buy CoinsDeposit CoinsInvest                                         4
# Buy CoinsSwapInvest                                                  3
# Buy CoinsInvestRead articles on Forum                                2
# Buy CoinsWithdraw coinsRead articles on Forum                        2
# Buy CoinsWithdraw coinsSwap                                          2
# Sell CoinsWithdraw coinsRead articles on Forum                       1
# ...

# %% [markdown]
# #### Analysing Respondents who used 4 Features

# %%
df_feature_usage_4 = df_feature_usage[df_feature_usage["Feature Used"]==4]

# %%
df_feature_usage_4['Feature Combined'] = df_feature_usage_4[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',
                                                             'Swap', 'Invest', 'Read articles on Forum',
                                                             'Participate in minigame on Forum']].fillna('').sum(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\4170822313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feature_usage_4['Feature Combined'] = df_feature_usage_4[['Buy Coins', 'Sell Coins', 'Withdraw coins', 'Deposit Coins',

# %%
df_feature_usage_4[['Feature Combined']].value_counts()
# Out:
# Feature Combined
# Buy CoinsSell CoinsWithdraw coinsDeposit Coins                                56
# Buy CoinsSell CoinsWithdraw coinsRead articles on Forum                        5
# Buy CoinsSell CoinsWithdraw coinsSwap                                          3
# Buy CoinsSell CoinsDeposit CoinsRead articles on Forum                         2
# Buy CoinsSell CoinsWithdraw coinsInvest                                        2
# Sell CoinsWithdraw coinsDeposit CoinsInvest                                    2
# Sell CoinsWithdraw coinsDeposit CoinsRead articles on Forum                    2
# Buy CoinsSell CoinsDeposit CoinsInvest                                         1
# Buy CoinsSell CoinsSwapInvest                                                  1
# Buy CoinsSell CoinsSwapRead articles on Forum                                  1
# Buy CoinsWithdraw coinsDeposit CoinsInvest                                     1
# ...

# %% [markdown]
# ### Analysing Survey Data (cont.) - Next Question

# %%
df[["Have you know about Altcoins?"]].value_counts()
# Out:
# Have you know about Altcoins?
# Yes                              457
# No                               453
# dtype: int64

# %%
df[["Name at least 1 Altcoin you have known 🧐"]].iloc[:,0].str.lower().value_counts()
# Out:
# bitcoin                                                            44
# litecoin                                                           24
# btc                                                                23
# eth                                                                22
# eos                                                                20
# ripple                                                             19
# xrp                                                                17
# ethereum                                                           15
# ada                                                                11
# bitcoin cash                                                       10
# bnb                                                                10
# tron                                                                8
# dogecoin                                                            7
# ...

# %%
df_alt_coin_list = df[["Name at least 1 Altcoin you have known 🧐"]].iloc[:,0].str.lower()

# %%
df_alt_coin_list.str.split(pat = ",").dropna().explode().str.strip().value_counts()
# Out:
# bitcoin                          44
# eth                              32
# litecoin                         27
# btc                              25
# eos                              24
# xrp                              21
# ripple                           20
# ethereum                         15
# bnb                              15
# bitcoin cash                     13
# ada                              13
# tron                             10
# bch                               8
# ltc                               8
# cardano                           8
# dogecoin                          7
# usdt                              7
# etherium                          6
# dash                              6
# binance                           6
# stellar                           5
# monero                            5
# no                                5
# altcoin                           4
# binance coin                      3
# neo                               3
# ...

# %% [markdown]
# #### Analysing - In 2020, if you have $10,000, which coins will you invest?

# %%
df[["Altcoins","BTC","ETH","USDT","LTC","XRP","BCH"]].count()
# Out:
# Altcoins    120
# BTC         301
# ETH         172
# USDT         72
# LTC          82
# XRP          84
# BCH          81
# dtype: int64

# %% [markdown]
# ### Analysing Survey Data (cont.) - Next Question

# %%
df[["If you could only choose 1 coin, which one would you invest? (choose only 1)"]].value_counts()
# Out:
# If you could only choose 1 coin, which one would you invest? (choose only 1)
# BTC                                                                             249
# One of Altcoins I like                                                           68
# ETH                                                                              65
# XRP                                                                              27
# LTC                                                                              17
# USDT                                                                             17
# BCH                                                                              14
# dtype: int64

# %%
df[["BTC","If you could only choose 1 coin, which one would you invest? (choose only 1)"]].value_counts()
# Out:
# BTC  If you could only choose 1 coin, which one would you invest? (choose only 1)
# BTC  BTC                                                                             227
#      One of Altcoins I like                                                           29
#      ETH                                                                              17
#      XRP                                                                               9
#      USDT                                                                              8
#      LTC                                                                               6
#      BCH                                                                               5
# dtype: int64

# %% [markdown]
# #### Analysing - Why not choose to invest in Altcoins?

# %%
df[["Because there are more risks (scam, fraud) than Bitcoin or top coin.","Because I got difficulty to own and store Altcoins."
    ,"Because of low liquidity.","Because I have a litte money.","Because I am lack of information about potential Altcoins."
    ,"Because the crypto exchange platforms I'm using don't have the Altcoins which I want to buy."
    ,"Because the budget of crypto market is very small in my portfolio.", "Other.2"]].count()
# Out:
# Because there are more risks (scam, fraud) than Bitcoin or top coin.                            121
# Because I got difficulty to own and store Altcoins.                                              42
# Because of low liquidity.                                                                        75
# Because I have a litte money.                                                                    78
# Because I am lack of information about potential Altcoins.                                       69
# Because the crypto exchange platforms I'm using don't have the Altcoins which I want to buy.     40
# Because the budget of crypto market is very small in my portfolio.                               26
# Other.2                                                                                          17
# dtype: int64

# %% [markdown]
# ### Analysing Survey Data (cont.) - Next Question

# %%
df[["What will help you change your mind and be willing to invest Altcoin?"]].dropna()
# Out:
#                                                                                                                                                                                                  What will help you change your mind and be willing to invest Altcoin?
# 1                                                                                                                                                                                                                                                 Daily ROI Investment
# 7                                                                                                                                                                                                                           If I can generate enough income for myself
# ...

# %%
df[["Why did you choose to invest Altcoins?"]].dropna()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Why did you choose to invest Altcoins?
# ...

# %%
df[["How many percentage of total budget are you going to invest in Altcoin? (type the number 0 - 100)"]].value_counts()
# Out:
# How many percentage of total budget are you going to invest in Altcoin? (type the number 0 - 100)
# 50                                                                                                   15
# 100                                                                                                  13
# 70                                                                                                   11
# 20                                                                                                    9
# 30                                                                                                    8
# 60                                                                                                    8
# 40                                                                                                    8
# 10                                                                                                    6
# ...

# %%
df[["What is your strategy in the altcoin investment ? (choose only 1)"]].value_counts()
# Out:
# What is your strategy in the altcoin investment ? (choose only 1)
# Long-term investment more than 1 year                                34
# Swing Trading - under 2 weeks                                        24
# Medium-term investment 6 months - 1 year                             20
# Short-term investment 1 -3 months                                    20
# Swing Trading - under 1 month                                        13
# Short-term investment 3-6 months                                      8
# dtype: int64

# %%
df[["Other.3"]].value_counts()
# Out:
# Other.3
# buy low sell high weekly    1
# dtype: int64

# %%
df[["Where do you store your altcoin? (choose only 1)"]].value_counts()
# Out:
# Where do you store your altcoin? (choose only 1)
# Online wallets (For example: Blockchain )                 57
# On the exchange platform                                  38
# Do not store Altcoins, I change them to the main coin.    12
# Cold wallets                                               9
# dtype: int64

# %%
df[["Other.4"]].value_counts()
# Out:
# Other.4
# Bank account    1
# No              1
# PC Wallet       1
# no              1
# dtype: int64

# %%
df[["I got difficulties in owning and storing Altcoins.","The exchange is low liquidity.","I have low invest budget"
    ,"I am lack of information about potential Altcoins.", "The crypto exchange platforms I'm using don't have the Altcoins which I want to buy."
   ,"The budget of crypto market is very small in my portfolio.","There are more risks (scam, fraud) than Bitcoin or top coin.","Other.5"]].count()
# Out:
# I got difficulties in owning and storing Altcoins.                                      24
# The exchange is low liquidity.                                                          21
# I have low invest budget                                                                48
# I am lack of information about potential Altcoins.                                      35
# The crypto exchange platforms I'm using don't have the Altcoins which I want to buy.    22
# The budget of crypto market is very small in my portfolio.                              13
# There are more risks (scam, fraud) than Bitcoin or top coin.                            35
# Other.5                                                                                  3
# dtype: int64

# %%
df[["Which is the most difficult thing? (choose 1)"]].value_counts()
# Out:
# Which is the most difficult thing? (choose 1)
# I have low invest budget                                                                36
# There are more risks (scam, fraud) than Bitcoin or top coin.                            19
# I got difficulties in owning and storing Altcoins.                                      17
# The exchange is low liquidity.                                                          16
# The crypto exchange platforms I'm using don't have the Altcoins which I want to buy.    15
# I am lack of information about potential Altcoins.                                      14
# The budget of crypto market is very small in my portfolio.                               1
# dtype: int64

# %%
df[["Other.6"]].value_counts()
# Out:
# Other.6
# mybank is not among listed banks on remitano    1
# no                                              1
# dtype: int64

# %%
df[["Name the most potential Altcoins you can't miss, you should invest now."]].iloc[:,0].str.lower().value_counts()
# Out:
# btc                                                                                                       8
# ada                                                                                                       5
# bitcoin                                                                                                   5
# eth                                                                                                       5
# ripple                                                                                                    3
# tron                                                                                                      3
# trx                                                                                                       3
# zcash                                                                                                     2
# bnb                                                                                                       2
# ...

# %%
df_most_potential_altcoin = df[["Name the most potential Altcoins you can't miss, you should invest now."]].iloc[:,0].str.lower()

# %%
df_most_potential_altcoin.str.split(pat = ",").dropna().explode().str.strip().value_counts()
# Out:
# btc                                          9
# eth                                          6
# ripple                                       5
# ada                                          5
# bitcoin                                      5
# cardano                                      4
# tron                                         4
# eos                                          4
# stellar                                      3
# bnb                                          3
# ethereum                                     3
# trx                                          3
# b                                            2
# bsv                                          2
# litecoin                                     2
# zcash                                        2
# no                                           2
# bitcoin cash                                 2
# kbc                                          2
# neo                                          2
# ...

# %%
df[["How did you buy Altcoins?"]].dropna()
# Out:
#                                                                                                                                                                      How did you buy Altcoins?
# 13                                                                                                                                                                                    remitano
# 16                                                                                                                                                                                  Mua qua ví
# 17                                                                                                                                                                       swap with other coins
# 21                                                                                                                                                                             trough exchange
# ...

# %%
df[["What is the most difficult thing about buying Altcoins?"]].dropna()
# Out:
#                                                                                                                                                                                                                                                                    What is the most difficult thing about buying Altcoins?
# 13                                                                                                                                                                                                                                                                                                                    scam
# 16                                                                                                                                                                                                                                                                                                         Vấn đề kinh phí
# ...

# %%
df[["If you have Altcoin, how did you sell Altcoins?"]].dropna()
# Out:
#                                                                                                                         If you have Altcoin, how did you sell Altcoins?
# 13                                                                                                                                                             remitano
# 16                                                                                                                                               Giao dịch qua reminato
# 17                                                                                                                                                     through remitano
# 21                                                                                                                                              depend on price offered
# ...

# %%
df[["What is the most difficult thing about selling Altcoin?"]].dropna()
# Out:
#                                                                                                                                                What is the most difficult thing about selling Altcoin?
# 13                                                                                                                                                                                               limit
# 16                                                                                                                                                                                Không có gì khó khăn
# 17                                                                                                                                                                                            scammers
# ...

# %%
df[["In your opinion, what should Remitano do to help you trade Altcoins easily?"]].dropna()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               In your opinion, what should Remitano do to help you trade Altcoins easily?
# ...

# %% [markdown]
# #### Analysing - With the following ideas, which one do you love?

# %%
df[["I can buy/sell all Altcoins at \"P2P exchange\".","I can \"Swap\" from BTC / ETH / UST to all Altcoins and vice versa."
    ,"I can \"Swap\" from my fiat-currency to all Altcoins and vice versa.", "I can \"Invest\" in all Altcoins."
    ,"I can store and deposit/withdraw all altcoins in \"Remitano wallet\"."
    ,"I can add my new Altcoin (which I create) on Remitano system."]].count()
# Out:
# I can buy/sell all Altcoins at "P2P exchange".                         262
# I can "Swap" from BTC / ETH / UST to all Altcoins and vice versa.      222
# I can "Swap" from my fiat-currency to all Altcoins and vice versa.     146
# I can "Invest" in all Altcoins.                                        128
# I can store and deposit/withdraw all altcoins in "Remitano wallet".    176
# I can add my new Altcoin (which I create) on Remitano system.           92
# dtype: int64

# %% [markdown]
# #### Ideas Scoring

# %%
df[["I can buy/sell all Altcoins at \"P2P exchange\"..1"]].value_counts()
# Out:
# I can buy/sell all Altcoins at "P2P exchange"..1
# 10.0                                                203
# 8.0                                                  60
# 9.0                                                  41
# 5.0                                                  34
# 6.0                                                  30
# 7.0                                                  29
# 0.0                                                  23
# 1.0                                                  20
# 4.0                                                   7
# 3.0                                                   6
# 2.0                                                   4
# dtype: int64

# %%
def get_score(question):
    print(question)
    sum_of_score = sum(df[[question]].value_counts())
    return sum(df[[question]].value_counts().index.to_series().apply(lambda x: int(x[0])) 
               * df[[question]].value_counts())/sum_of_score

# %%
get_score("I can buy/sell all Altcoins at \"P2P exchange\"..1")
# Out:
# I can buy/sell all Altcoins at "P2P exchange"..1
# 7.671772428884026

# %%
df[["I can \"Swap\" from BTC / ETH / UST to all Altcoins and vice versa..1"]].value_counts()
# Out:
# I can "Swap" from BTC / ETH / UST to all Altcoins and vice versa..1
# 10.0                                                                   200
# 8.0                                                                     62
# 7.0                                                                     42
# 9.0                                                                     39
# 5.0                                                                     33
# 6.0                                                                     23
# 0.0                                                                     22
# 1.0                                                                     15
# 4.0                                                                      9
# 2.0                                                                      7
# 3.0                                                                      5
# dtype: int64

# %%
get_score("I can \"Swap\" from BTC / ETH / UST to all Altcoins and vice versa..1")
# Out:
# I can "Swap" from BTC / ETH / UST to all Altcoins and vice versa..1
# 7.711159737417943

# %%
df[["I can \"Swap\" from my fiat-currency to all Altcoins and vice versa..1"]].value_counts()
# Out:
# I can "Swap" from my fiat-currency to all Altcoins and vice versa..1
# 10.0                                                                    199
# 8.0                                                                      54
# 9.0                                                                      52
# 5.0                                                                      41
# 7.0                                                                      30
# 0.0                                                                      23
# 6.0                                                                      17
# 4.0                                                                      16
# 1.0                                                                      13
# 2.0                                                                       8
# 3.0                                                                       4
# dtype: int64

# %%
get_score("I can \"Swap\" from my fiat-currency to all Altcoins and vice versa..1")
# Out:
# I can "Swap" from my fiat-currency to all Altcoins and vice versa..1
# 7.6849015317286655

# %%
df[["I can \"Invest\" in all Altcoins..1"]].value_counts()
# Out:
# I can "Invest" in all Altcoins..1
# 10.0                                 191
# 8.0                                   52
# 7.0                                   41
# 9.0                                   40
# 5.0                                   38
# 6.0                                   29
# 0.0                                   26
# 1.0                                   15
# 4.0                                   12
# 3.0                                    9
# 2.0                                    4
# dtype: int64

# %%
get_score("I can \"Invest\" in all Altcoins..1")
# Out:
# I can "Invest" in all Altcoins..1
# 7.516411378555799

# %%
df[["I can store and deposit/withdraw all altcoins in \"Remitano wallet\"..1"]].value_counts()
# Out:
# I can store and deposit/withdraw all altcoins in "Remitano wallet"..1
# 10.0                                                                     224
# 8.0                                                                       64
# 9.0                                                                       47
# 5.0                                                                       33
# 7.0                                                                       30
# 1.0                                                                       15
# 0.0                                                                       13
# 6.0                                                                       13
# 4.0                                                                        7
# 3.0                                                                        6
# 2.0                                                                        5
# dtype: int64

# %%
get_score("I can store and deposit/withdraw all altcoins in \"Remitano wallet\"..1")
# Out:
# I can store and deposit/withdraw all altcoins in "Remitano wallet"..1
# 8.094091903719912

# %%
df[["I can add my new Altcoin (which I create) on Remitano system..1"]].value_counts()
# Out:
# I can add my new Altcoin (which I create) on Remitano system..1
# 10.0                                                               171
# 5.0                                                                 49
# 8.0                                                                 49
# 0.0                                                                 37
# 9.0                                                                 37
# 7.0                                                                 33
# 6.0                                                                 30
# 1.0                                                                 17
# 4.0                                                                 14
# 3.0                                                                 12
# 2.0                                                                  8
# dtype: int64

# %%
get_score("I can add my new Altcoin (which I create) on Remitano system..1")
# Out:
# I can add my new Altcoin (which I create) on Remitano system..1
# 7.037199124726477

# %% [markdown]
# ### Analysing Survey Data (cont.) - Next Question

# %%
df[["If there is only 1 vote, which one do you prefer?"]].value_counts()
# Out:
# If there is only 1 vote, which one do you prefer?
# I can buy/sell all Altcoins at "P2P exchange".                         176
# I can "Swap" from BTC / ETH / UST to all Altcoins and vice versa.      106
# I can store and deposit/withdraw all altcoins in "Remitano wallet".     64
# I can "Swap" from my fiat-currency to all Altcoins and vice versa.      53
# I can "Invest" in all Altcoins.                                         35
# I can add my new Altcoin (which I create) on Remitano system.           23
# dtype: int64

# %% [markdown]
# #### Analysing - You are trading Altcoins on which crypto exchange currently?

# %%
df[["Coinbas và Coinbase Pro","Bittrex"
    ,"Changelly", "Binance","Kraken","KuCoin","BitMEX","Huobi Pro","Bitpanda","Remitano"]].count()
# Out:
# Coinbas và Coinbase Pro    13
# Bittrex                    25
# Changelly                  10
# Binance                    55
# Kraken                      4
# KuCoin                      8
# BitMEX                      5
# Huobi Pro                   7
# Bitpanda                    4
# Remitano                   64
# dtype: int64

# %% [markdown]
# #### Analysing Number of Exchanges Used per Respondent

# %%
df_exchange = df[["#","Coinbas và Coinbase Pro","Bittrex","Changelly", "Binance","Kraken","KuCoin","BitMEX","Huobi Pro","Bitpanda","Remitano"]]

# %%
df_exchange["Exchange Used"] = df_exchange[["Coinbas và Coinbase Pro","Bittrex","Changelly", 
                                            "Binance","Kraken","KuCoin","BitMEX","Huobi Pro","Bitpanda","Remitano"]].count(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\2111477101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exchange["Exchange Used"] = df_exchange[["Coinbas và Coinbase Pro","Bittrex","Changelly",

# %%
df_exchange[["Exchange Used"]].value_counts()
# Out:
# Exchange Used
# 0                799
# 1                 68
# 2                 20
# 3                 12
# 4                  9
# 5                  1
# 10                 1
# dtype: int64

# %% [markdown]
# #### Analysing Respondents who only used 1 Exchange

# %%
df_exchange_1 = df_exchange[df_exchange["Exchange Used"]==1]

# %%
df_exchange_1['Exchange'] = df_exchange_1[["Coinbas và Coinbase Pro","Bittrex","Changelly",
                                           "Binance","Kraken","KuCoin","BitMEX","Huobi Pro","Bitpanda","Remitano"]].fillna(method='bfill', axis=1).iloc[:, 0]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\2527270889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exchange_1['Exchange'] = df_exchange_1[["Coinbas và Coinbase Pro","Bittrex","Changelly",

# %%
df_exchange_1[["Exchange"]].value_counts()
# Out:
# Exchange
# Remitano                   32
# Binance                    20
# Coinbas và Coinbase Pro     6
# Bittrex                     4
# Bitpanda                    2
# Changelly                   2
# Huobi Pro                   1
# KuCoin                      1
# dtype: int64

# %% [markdown]
# #### Analysing Respondents who used 2 Exchanges

# %%
df_exchange_2 = df_exchange[df_exchange["Exchange Used"]==2]

# %%
df_exchange_2['Exchange Combined'] = df_exchange_2[["Coinbas và Coinbase Pro","Bittrex","Changelly",
                                                   "Binance","Kraken","KuCoin","BitMEX","Huobi Pro","Bitpanda","Remitano"]].fillna('').sum(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17656\2659413660.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exchange_2['Exchange Combined'] = df_exchange_2[["Coinbas và Coinbase Pro","Bittrex","Changelly",

# %%
df_exchange_2[["Exchange Combined"]].value_counts()
# Out:
# Exchange Combined
# BinanceRemitano                   6
# BittrexBinance                    5
# BittrexRemitano                   2
# ChangellyRemitano                 2
# BinanceKraken                     1
# ChangellyBinance                  1
# Coinbas và Coinbase ProBinance    1
# Coinbas và Coinbase ProBittrex    1
# Huobi ProRemitano                 1
# dtype: int64

# %% [markdown]
# ### Additional Check - Demographic Data vs Coin Preference

# %%
df[['Where are you from?','If you could only choose 1 coin, which one would you invest? (choose only 1)']].value_counts()
# Out:
# Where are you from?  If you could only choose 1 coin, which one would you invest? (choose only 1)
# Nigeria              BTC                                                                             81
# Malaysia             BTC                                                                             62
# Vietnam              BTC                                                                             25
# Malaysia             One of Altcoins I like                                                          23
# Vietnam              ETH                                                                             21
# India                BTC                                                                             21
# Nigeria              ETH                                                                             17
# Malaysia             ETH                                                                             15
# ...

# %%
df.groupby(['Where are you from?','If you could only choose 1 coin, which one would you invest? (choose only 1)']).agg({'Where are you from?':['count']})
# Out:
#                                                                                                  Where are you from?
#                                                                                                                count
# Where are you from? If you could only choose 1 coin, which one would you invest? (choose only 1)
# India               BCH                                                                                            1
#                     BTC                                                                                           21
#                     ETH                                                                                            2
#                     LTC                                                                                            2
#                     One of Altcoins I like                                                                         5
# ...
